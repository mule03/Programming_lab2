# %% [markdown]
# PANDAS

# %% [markdown]
# DATI MISTI
#
# in numpy non si posso salvare valori misti

# %%
import numpy as np

a=np.array([6.1,150.0,25,'A-'])
b=np.array([7.1,150.0,24,'B-'])
a + b
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       3 a=np.array([6.1,150.0,25,'A-'])
#       4 b=np.array([7.1,150.0,24,'B-'])
# ----> 5 a + b
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> None

# %% [markdown]
# CON PANDAS SI PUO'

# %%
# %conda install pandas
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-2.2.3               |  py312hcf29cfe_0        14.6 MB
#     ------------------------------------------------------------
#                                            Total:        14.6 MB
#
# The following packages will be UPDATED:
#
#   pandas                              2.2.2-py312hd77ebd4_0 --> 2.2.3-py312hcf29cfe_0
#
#
#
# ...
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# SERIES
#
# Si crea un array unidimensiona ma ho un indicizzazione, ad ogni elemento associo un indicie

# %%
import pandas as pd

data = [10,20,30,40,50]

series= pd.Series(data,index=['a','b','c','d','e'])
series

series.index #per trovare gli indici
series.values #per trovare i valori
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# DATAFRAME
#
# ogni colonna e riga ha un certa etichetta come se fossimo in excel

# %%
data = { #è un dizionario
    'job_title': ['Data Analyst', 'Data Scientist', 'Data Engineer'], #prima dei : avremo in nome della colonna
    'location': ['Italy', 'USA', 'Germany'],
    'salary': [40000, 80000, 70000],
    'date_posted': ['2024-12-01', '2024-11-15', '2024-12-10']  # formato YYYY-MM-DD
}

df = pd.DataFrame(data) #creo un dataframe con i dati di data
df



print(df['job_title'])#per trovare i dati di una colonna 

print(df.job_title)#oppure:
print(df.columns) #stampar ei nomi delle colonne
# Out:
# 0      Data Analyst
# 1    Data Scientist
# 2     Data Engineer
# Name: job_title, dtype: object
# 0      Data Analyst
# 1    Data Scientist
# 2     Data Engineer
# Name: job_title, dtype: object
# Index(['job_title', 'location', 'salary', 'date_posted'], dtype='object')

# %% [markdown]
# CARICAMENTO DATI PER I DATAFRAME

# %%
df=pd.read_csv('shampoo_sales.csv')
df
# Out:
#          Date  Sales
# 0  01-01-2012  266.0
# 1  01-02-2012  145.9
# 2  01-03-2012  183.1
# 3  01-04-2012  119.3
# 4  01-05-2012  180.3
# 5  01-06-2012  168.5
# 6  01-07-2012  231.8
# 7  01-08-2012  224.5
# 8  01-09-2012  192.8
# 9  01-10-2012  122.9

# %% [markdown]
# PRENDERE DEI DATA SET ONLINE

# %%
import seaborn as sns

df = sns.load_dataset("titanic")
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# data set qualità del vino TRAMITE URL
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
df = pd.read_csv(url, sep=';') 
print(df.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# dataset consumo di alcol TRAMITE GITHUB
df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv")
print(df.head())

# %%
#USIAMO QUESTO

# %conda install datasets
from datasets import load_dataset
# Carica il dataset
dataset = load_dataset("yiqing111/Engineering_Jobs_Insight_Dataset")

# Converte in DataFrame Pandas
df = dataset['train'].to_pandas()

df
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - datasets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     datasets-3.3.2             |  py312hca03da5_0         849 KB
#     huggingface_hub-0.29.2     |  py312hca03da5_0         679 KB
#     multiprocess-0.70.15       |  py312hca03da5_0         320 KB
#     python-xxhash-3.5.0        |  py312h80987f9_0          21 KB
#     xxhash-0.8.0               |       h1a28f6b_3          80 KB
#     ------------------------------------------------------------
#                                            Total:         1.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   datasets           pkgs/main/osx-arm64::datasets-3.3.2-py312hca03da5_0
# ...

# %% [markdown]
# VISUALIZZAZIONI DATASET

# %%
df.head()#prime tot righe
df.tail()#ultime righe
# Out:
#                                                Job Title         Company  \
# 11180  Blockchain Developer (The Decentralization Arc...     Unreal Gigs
# 11181  Blockchain Developer (The Decentralization Arc...     Unreal Gigs
# 11182                   Blockchain Developer (Rust/Move)           Supra
# 11183  Blockchain Ecosystem Developer Advocate - USA ...  Crypto Recruit
# 11184            Backend Developer - Java JVM Blockchain  Crypto Recruit
#
#                                              Description  \
# 11180  Do you have a passion for decentralized system...
# 11181  Do you have a passion for decentralized system...
# 11182  Who We Are Supra is pioneering the future of i...
# 11183  Hyperfast blockchain building out ecosystem gl...
# 11184  US HQ Blockchain seeking Java JVM Senior Devs ...
#
#                         Location  Salary Min  Salary Max  \
# 11180  San Francisco, California   110000.00   160000.00
# 11181      Austin, Travis County   110000.00   160000.00
# ...

# %% [markdown]
# OTTENERE INFORMAZIONI

# %%
df.info() #informaizoni sul dataaseet
df.describe() #statistiche sulle colonne
df['Job Title'].unique() #Restituisce i valori distinti presenti in una colonna. utile se voglio raggurparre i valori
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11185 entries, 0 to 11184
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Job Title    11185 non-null  object
#  1   Company      11181 non-null  object
#  2   Description  11185 non-null  object
#  3   Location     11185 non-null  object
#  4   Salary Min   11185 non-null  float64
#  5   Salary Max   11179 non-null  float64
#  6   Date Posted  11185 non-null  object
#  7   URL          11185 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 699.2+ KB
# array(['Senior Software Engineer (Python)',
#        'Sr. Backend Software Engineer', 'Sr. Software Engineer - Mobile',
#        ..., 'Blockchain Developer (Rust/Move)',
#        'Blockchain Ecosystem Developer Advocate - USA Canada',
#        'Backend Developer - Java JVM Blockchain'], dtype=object)

# %% [markdown]
# Ma esistono anche altri modi per ottenere una panoramica del DataFrame, come:
#
# len(df) - Ottiene la lunghezza del DataFrame (numero di righe).
# df.shape - Restituisce una tupla con il numero di righe e colonne (righe, colonne).
# df.index - Descrive l'indice del DataFrame.
# df.columns - Elenca i nomi delle colonne del DataFrame.
# df.count() - Conta il numero di valori non nulli per ogni colonna.
# df['column_name'].unique() - Restituisce i valori distinti presenti in una colonna.

# %% [markdown]
# ACCESSO AI DATI

# %% [markdown]
# COLONNE

# %%
df.columns #elenco colonne
df.columns = df.columns.str.replace(' ', '_')#dato che c'è lo spazio cambio lo spazio con un _
df.Job_Title #dati della colonna
df[['Job_Title', 'Location']] #più colonne
# Out:
#                                                Job_Title  \
# 0                      Senior Software Engineer (Python)
# 1                          Sr. Backend Software Engineer
# 2                         Sr. Software Engineer - Mobile
# 3                          Acquisition Software Engineer
# 4                               Senior Software Engineer
# ...                                                  ...
# 11180  Blockchain Developer (The Decentralization Arc...
# 11181  Blockchain Developer (The Decentralization Arc...
# 11182                   Blockchain Developer (Rust/Move)
# 11183  Blockchain Ecosystem Developer Advocate - USA ...
# 11184            Backend Developer - Java JVM Blockchain
#
#                         Location
# 0             Crestwood, Houston
# 1           Belmont, Kent County
# 2           Belmont, Kent County
# 3        China Lake, Kern County
# 4             Richardson, Dallas
# ...                          ...
# 11180  San Francisco, California
# ...

# %% [markdown]
# RIGHE

# %%
df.iloc[1] #VALORI DI OGNI COLONNA CHE HANNO INDICE CRRISPONDERE DI QUELLA RIGA
df.iloc[2:5] #insime di righe
df.iloc[2:5, 0:2] #righe e colonne
df.loc["Monday"]

#si possono filtrare le righe
df[df['Salary_Min'] > 100000]
df['Salary_Min'] > 100000
df[df['Job_Title'] == 'Senior Software Engineer']#tutte le righe che ahnno come valore di job ttle, senio software...

#per le condizioni ligiche più complesse non si usano and e or ma si usano & e |
df[(df.Job_Title == 'Senior Software Engineer') & (df.Salary_Min > 200000)]
# Out:
#                      Job_Title                     Company  \
# 4     Senior Software Engineer                      Innova
# 434   Senior Software Engineer            Komodo Co., Ltd.
# 436   Senior Software Engineer                Tech Firefly
# 439   Senior Software Engineer                  GrowthBook
# 440   Senior Software Engineer                     Aviture
# ...                        ...                         ...
# 1472  Senior Software Engineer           Digital Corporate
# 1485  Senior Software Engineer                     Antares
# 1490  Senior Software Engineer     The Walt Disney Company
# 1493  Senior Software Engineer  Parsons Technical Services
# 1496  Senior Software Engineer             Mercer Advisors
#
#                                             Description  \
# 4     A client of Innova Solutions is immediately hi...
# 434   About KOMODO KOMODO works on products that sha...
# 436   Tech Firefly is teaming up with a deep learnin...
# ...

# %% [markdown]
# TROVARE VALORI NON NULLI

# %%
df.Salary_Max.notna() #ottengo se i valori di una colonna sono mancano o no
df[df['Salary_Max'].notna()] #Se vogliamo ottenere solo le righe senza valori mancanti in una colonna specifica, possiamo usare:

df[(df.Job_Title == 'Senior Software Engineer') & (df.Salary_Max.notna())]
# Out:
#                                                Job_Title  \
# 0                      Senior Software Engineer (Python)
# 1                          Sr. Backend Software Engineer
# 2                         Sr. Software Engineer - Mobile
# 3                          Acquisition Software Engineer
# 4                               Senior Software Engineer
# ...                                                  ...
# 11180  Blockchain Developer (The Decentralization Arc...
# 11181  Blockchain Developer (The Decentralization Arc...
# 11182                   Blockchain Developer (Rust/Move)
# 11183  Blockchain Ecosystem Developer Advocate - USA ...
# 11184            Backend Developer - Java JVM Blockchain
#
#                           Company  \
# 0                       BP Energy
# 1                          Meijer
# 2                          Meijer
# 3      Naval Air Systems Command
# 4                          Innova
# ...                           ...
# ...

# %% [markdown]
# seconda parte: MANIPOLAZIONE DEI DATAFRAME

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset

# Carica il dataset
dataset = load_dataset("yiqing111/Engineering_Jobs_Insight_Dataset")

# Converte in DataFrame Pandas
df = dataset['train'].to_pandas()
# Rimpiazza gli spazi con l'underscore
df.columns = df.columns.str.replace(' ', '_')

# %% [markdown]
# DATE E TEMPO
# dt: è un accessor che ci permette di accedere a metodi e proprietà specializzate per lavorare con dati datetime all'interno di una series di pandas.
# date: è una proprietà che estrae la componente data da un oggetto datetime nella series.

# %%
# Convertire 'Date_Posted' in datetime senza specificare il formato esatto
df['Date_Posted'] = pd.to_datetime(df['Date_Posted'], errors='coerce')
# errors='coerce' trasforma quelli non validi in NaT (Not a Time, l'equivalente datetime di NaN)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11185 entries, 0 to 11184
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Job_Title    11185 non-null  object
#  1   Company      11181 non-null  object
#  2   Description  11185 non-null  object
#  3   Location     11185 non-null  object
#  4   Salary_Min   11185 non-null  float64
#  5   Salary_Max   11179 non-null  float64
#  6   Date_Posted  11185 non-null  datetime64[ns, UTC]
#  7   URL          11185 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(2), object(5)
# memory usage: 699.2+ KB
#                            Job_Title                     Company  \
# 0  Senior Software Engineer (Python)                   BP Energy
# 1      Sr. Backend Software Engineer                      Meijer
# 2     Sr. Software Engineer - Mobile                      Meijer
# 3      Acquisition Software Engineer  Naval Air Systems Command
# ...

# %%
#Ora convertiamo un valore da datetime a data utilizzando dt.date.

df['Date_Posted'] = df['Date_Posted'].dt.date

df.head()
# Out:
#                            Job_Title                     Company  \
# 0  Senior Software Engineer (Python)                   BP Energy
# 1      Sr. Backend Software Engineer                      Meijer
# 2     Sr. Software Engineer - Mobile                      Meijer
# 3      Acquisition Software Engineer  Naval Air Systems Command
# 4           Senior Software Engineer                      Innova
#
#                                          Description                 Location  \
# 0  Entity: Trading & Shipping Job Family Group: S...       Crestwood, Houston
# 1  As a family company, we serve people and commu...     Belmont, Kent County
# 2  As a family company, we serve people and commu...     Belmont, Kent County
# 3  Position Description The Harpoon/SLAM ER/JSOW ...  China Lake, Kern County
# 4  A client of Innova Solutions is immediately hi...       Richardson, Dallas
#
#    Salary_Min  Salary_Max Date_Posted  \
# 0   138992.40   138992.40  2024-10-29
# ...

# %% [markdown]
# CREAZIONE COLONNA
#
# Qui stiamo creando una nuova colonna chiamata 'Is Senior Software Engineer'.
# La colonna conterrà:
#
# 1 se il valore in Job_Title è uguale a 'Senior Software Engineer'
# 0 altrimenti
# Usiamo astype(int) per convertire il valore booleano in 1 o 0.

# %%
df['is_Senior_SE'] = (df.Job_Title == 'Senior Software Engineer').astype(int)
df['is_Senior_SE']
df[df['is_Senior_SE'] > 0] #Possiamo usare il filtro sulle righe che abbiamo visto nella sezione precedente:
# Out:
#                      Job_Title                     Company  \
# 4     Senior Software Engineer                      Innova
# 434   Senior Software Engineer            Komodo Co., Ltd.
# 436   Senior Software Engineer                Tech Firefly
# 439   Senior Software Engineer                  GrowthBook
# 440   Senior Software Engineer                     Aviture
# ...                        ...                         ...
# 1485  Senior Software Engineer                     Antares
# 1488  Senior Software Engineer                       Ludus
# 1490  Senior Software Engineer     The Walt Disney Company
# 1493  Senior Software Engineer  Parsons Technical Services
# 1496  Senior Software Engineer             Mercer Advisors
#
#                                             Description  \
# 4     A client of Innova Solutions is immediately hi...
# 434   About KOMODO KOMODO works on products that sha...
# 436   Tech Firefly is teaming up with a deep learnin...
# ...

# %% [markdown]
# ELIMINARE DATI
#
# Usa drop() se vuoi eliminare (cancellare) una colonna o una riga dal tuo DataFrame.
#
# La sintassi è:
#
# Eliminare una colonna:
#
# df.drop('nome_colonna', axis=1)
# Eliminare una riga:
#
# df.drop(indice, axis=0)
# Se vuoi eliminare più elementi:
#
# Eliminare più colonne:
#
# df.drop(['colonna1', 'colonna2'], axis=1)
# Eliminare più righe:
#
# df.drop([indice1, indice2], axis=0)

# %%
df.info()
df.drop('URL', axis = 1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11185 entries, 0 to 11184
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Job_Title     11185 non-null  object
#  1   Company       11181 non-null  object
#  2   Description   11185 non-null  object
#  3   Location      11185 non-null  object
#  4   Salary_Min    11185 non-null  float64
#  5   Salary_Max    11179 non-null  float64
#  6   Date_Posted   11185 non-null  object
#  7   URL           11185 non-null  object
#  8   is_Senior_SE  11185 non-null  int64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 786.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11185 entries, 0 to 11184
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Job_Title     11185 non-null  object
#  1   Company       11181 non-null  object
#  2   Description   11185 non-null  object
# ...

# %% [markdown]
# VALORI NULLI
#
# Per rimuovere le righe che contengono celle vuote (NaN), usa dropna().
# Per default, dropna() restituisce un nuovo DataFrame e non modifica quello originale.
# Se vuoi che dropna() modifichi direttamente il DataFrame originale, devi usare il parametro inplace=True

# %%
df.dropna(subset=['Salary_Max'], inplace=True)

# %% [markdown]
# Ordinamento dei Valori
# sort_values() ordina un DataFrame o una specifica colonna in ordine crescente o decrescente, basandosi su una o più colonne.
# Di solito si usa per ordinare secondo una colonna specifica.
# Parametri:
# by - nome della colonna (o lista di colonne) su cui basare l’ordinamento.
# ascending - booleano o lista di booleani. Di default è True (ordine crescente). Per ordinare in modo decrescente, si usa False.
# inplace - se True, modifica il DataFrame originale; altrimenti restituisce uno nuovo.

# %%
#Ordiniamo il nostro DataFrame secondo la colonna Date_Posted in ordine decrescente (dalla data più recente alla meno recente).
df.sort_values(by='Date_Posted', ascending=False, inplace=True)
df
# Out:
#                                                Job_Title  \
# 7998                        Lead Cloud Platform Engineer
# 10526                     Database Administrator, Senior
# 7909                               Senior Cloud Engineer
# 2862   Applied AI ML Director, Principal Machine Lear...
# 7944                    Snowflake & Azure Cloud Engineer
# ...                                                  ...
# 5840                     Business Analyst in New York eg
# 10279  Embedded Software Engineer – Sensors – Electri...
# 1028                           Backend Software Engineer
# 7296                                     DevOps Engineer
# 1029                   CryptoCurrency- Software Engineer
#
#                                  Company  \
# 7998                            Alcority
# 10526  Booz Allen Hamilton United States
# 7909                Fidelity Investments
# 2862                       JPMorganChase
# 7944                             Infosys
# ...

# %% [markdown]
# ANALISI DEI DATI CON PANDAS

# %%
df['Salary_Min'].describe() #DATI SOLO DELLA SINGOLA COLONNA
df.sum() #Somma dei valori

df.cumsum() #Somma cumulativa dei valori

df.min() / df.max() #Valori minimi / massimi

df.idxmin() / df.idxmax() #Indici dei valori minimo / massimo

df.mean() #Media dei valori

df.median() #Mediana dei valori

df.mode() #Moda dei valori

series.value_counts() #Conteggio dei valori unici all'interno di una Series (cioè una colonna)
# Out:
# count     11179.000000
# mean     110402.294154
# std       40849.746713
# min           0.000000
# 25%       83139.460000
# 50%      105012.470000
# 75%      133027.585000
# max      550000.000000
# Name: Salary_Min, dtype: float64

# %%
df['Salary_Min'].min() #mi dice il valore minimo
df['Salary_Min'].idxmin() #mi dice in che posizione si trova in base all'id
df.iloc[10982] #mi ritorna la riga rispetto a quell'id però sul dataframe iniziale
df.loc[10982] #mi ritorna la riga rispetto a quell'id però sul dataframe dove sono ora
# Out:
# Job_Title                      Senior Solutions Architect, Retail
# Company                                                Nvidia Usa
# Description     Interested in developing innovative NVIDIA AI ...
# Location                                             Arkansas, US
# Salary_Min                                                    0.0
# Salary_Max                                               339250.0
# Date_Posted                                            2024-11-24
# is_Senior_SE                                                    0
# Name: 10982, dtype: object

# %% [markdown]
# AGGREGAZIONE
# Groupby()
# Usa groupby per raggruppare il DataFrame in base ai valori unici di una colonna specifica.
# Permette di eseguire aggregazioni (es. media, somma) sui dati raggruppati.
# La sintassi è: df.groupby("colonne da raggruppare")["colonne da aggregare"].metodo_che_aggrega()
#
# Esempi di aggregazioni che puoi eseguire:
# mean() – Calcola la media dei gruppi
# sum() – Somma i valori di ciascun gruppo
# median() – Trova la mediana per ogni gruppo
# min() / max() – Valore minimo / massimo per gruppo
# Conteggi:
# count() – Conta i valori non nulli (non-NA) per ogni gruppo
# size() – Restituisce la dimensione totale del gruppo (inclusi i NaN)
# std() / var() – Deviazione standard e varianza
# first() / last() – Prima e ultima riga di ciascun gruppo
# unique() – Valori unici non-NaN per ciascun gruppo

# %%
df.groupby('Job_Title')['Salary_Min'].mean() #df.groupby("colonne da raggruppare")["colonne da aggregare"].metodo_che_aggrega()
# Out:
# Job_Title
#  Developer                                                                  116729.88
# (Hybrid) Algorithms/Video Engineer/AI/ML tech , Deep Learning framework/    116253.39
# (Marketing) Front End Developer, Full-Time, Marlboro, Hybrid                 82348.70
# (USA) Product Manager III                                                    90000.00
# (f2pool) DevOps Engineer                                                    130000.00
#                                                                               ...
# Zuora - Solution Architect - Manager                                        129817.80
# eCommerce Product Manager                                                   120000.00
# iOS Software Engineer                                                       130000.00
# racle Cloud Financials Solution Architect                                   114549.44
# ☁ Cloud HPC Engineer ☁                                                      130000.00
# ...

# %%
#con la funzione agg() posso effettualere molteplici aggregazioni conteporanemnte
df.groupby('Job_Title')['Salary_Min'].agg(['min', 'max', 'median'])
# Out:
#                                                           min
# Job_Title
#  Developer                                          116729.88
# (Hybrid) Algorithms/Video Engineer/AI/ML tech ,...  116253.39
# (Marketing) Front End Developer, Full-Time, Mar...   82348.70
# (USA) Product Manager III                            90000.00
# (f2pool) DevOps Engineer                            130000.00
# ...                                                       ...
# Zuora - Solution Architect - Manager                100000.00
# eCommerce Product Manager                           120000.00
# iOS Software Engineer                               130000.00
# racle Cloud Financials Solution Architect           114549.44
# ☁ Cloud HPC Engineer ☁                              130000.00
#
# [4842 rows x 1 columns]

# %% [markdown]
# PLOTTING SU PANDAS

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  


dataset = load_dataset("yiqing111/Engineering_Jobs_Insight_Dataset")
df = dataset['train'].to_pandas()
df.columns = df.columns.str.replace(' ', '_')
df['Date_Posted'] = pd.to_datetime(df['Date_Posted'], errors='coerce')
# Out:
# Repo card metadata block was not found. Setting CardData to empty.

# %%
job_counts = df['Job_Title'].value_counts()
job_counts = job_counts.head(6)
job_counts
# Out:
# Job_Title
# Software Engineer                                                         311
# Product Manager  Social app startup                                       282
# Associate Product Manager  Social app startup                             277
# 2025 Virtual Summer Intern Program - Product Analyst Intern (Xome)        267
# Real-Time Software Engineer                                               266
# Data Science Internship (Remote Eligible) - Graduate Student Preferred    255
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5, 3))  # imposta una dimensione più compatta
job_counts.plot(kind='bar')
plt.xlabel('')
plt.ylabel('Count of Postings')
plt.title('Job Postings by Job Title')
plt.xticks(rotation=45, ha='right') 
plt.show()
